# %%
import pandas as pd
from google.cloud import translate_v3 as translate
import os
import time

# Set up authentication
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/key.json'

# Initialize the Translation API client
translate_client = translate.TranslationServiceClient()

# Define your project details
project_id = 'daring-diode-408818'
location = 'global'

# Read the Excel file
df = pd.read_excel('/content/eng_captions.xlsx')

# Define a function to translate a batch of text
def translate_batch(texts, target_language):
    if texts:
        response = translate_client.translate_text(
            contents=texts,
            target_language_code=target_language,
            parent=f"projects/{project_id}/locations/{location}"
        )
        return [translation.translated_text for translation in response.translations]
    return texts

# Function to process the DataFrame in batches
def process_in_batches(df, column_name, target_language, batch_size=400):
    translated_texts = []
    batch_texts = []
    batch_counter = 0

    for text in df[column_name].fillna(""):  # Fill NaN with empty strings
        batch_texts.append(text)
        if len(batch_texts) == batch_size:
            batch_translations = translate_batch(batch_texts, target_language)
            translated_texts.extend(batch_translations)
            # Print the first few characters of the first item in each batch for verification
            print(f"Batch {batch_counter} processed. Sample translation: {batch_translations[0][:50]}")
            batch_texts = []
            batch_counter += 1
            time.sleep(15)  # Sleep for 60 seconds between batches

    # Process any remaining texts in the last batch
    if batch_texts:
        translated_texts.extend(translate_batch(batch_texts, target_language))

    return translated_texts

# Translate and update the DataFrame
df['translated_captions'] = process_in_batches(df, 'comment', 'ur')  # 'comment' is the column name

# Save the dataframe with the translations to a new Excel file
df.to_excel('/content/translated_captions.xlsx', index=False)
# Out:
# Batch 0 processed. Sample translation:  گھنے بالوں والے دو نوجوان صحن میں گھومتے ہوئے اپن
# Batch 1 processed. Sample translation:  ایک جوڑے اور ایک شیر خوار بچے، جو مرد کے ہاتھوں پ
# Batch 2 processed. Sample translation:  ایک لڑکی ایک بڑے دریا میں پیدل چل رہی ہے، جیسا کہ
# Batch 3 processed. Sample translation:  ایک سفید کتا کھلی آنکھوں کے ساتھ ٹائل والے فرش پر
# Batch 4 processed. Sample translation:  ایروڈینامک گیئر میں ایک آدمی تیز گھماؤ کے گرد سڑک
# Batch 5 processed. Sample translation:  ایک بھورا اور سفید اور ایک سیاہ اور سفید کتا سمند
# Batch 6 processed. Sample translation:  ایک بوڑھا آدمی صحن کا کام کر رہا ہے۔
# Batch 7 processed. Sample translation:  ایک بھورا کتا گھاس اور پھولوں میں سے دوڑ رہا ہے۔
# Batch 8 processed. Sample translation:  پانچ بالغ اپنے گھر کے پچھواڑے میں پکنک کی میز پر
# Batch 9 processed. Sample translation:  دو آدمی، ایک اپنے ساتھ ڈرم کے ساتھ سکرین کو دیکھ
# Batch 10 processed. Sample translation:  گہرے کمبل میں لپٹی ہوئی ایک چھوٹی سی لڑکی ہجوم سے
# Batch 11 processed. Sample translation:  ایک سفید کتا جس پر سرخ پٹے ہیں پیچھے مڑ کر دیکھ ر
# Batch 12 processed. Sample translation:  یونیفارم اور صفائی کی ٹوپیاں پہنے ایک درجن کارکن
# Batch 13 processed. Sample translation:  آدمی سرخ لباس اور ہیلس پہنے ایک گڑیا کے ساتھ رقص
# Batch 14 processed. Sample translation:  مجسمہ آزادی کی ٹوپی پہنے دو خواتین سب وے میں اپنی
# Batch 15 processed. Sample translation:  ایک آدمی کھیل کے میدان کی پلاسٹک ٹیوب کے ذریعے سر
# Batch 16 processed. Sample translation:  ایک آدمی ایک کرسی پر بیٹھا ہے جس کی پشت پر جیکٹ ل
# Batch 17 processed. Sample translation:  نیلی وردی میں ملبوس ایک نوجوان عورت ڈیجیٹل تصاویر
# Batch 18 processed. Sample translation:  جوتے پہنے سلور کار کے سامنے ایک نوجوان لڑکی، کچھ
# Batch 19 processed. Sample translation:  دھاری دار بلاؤز پہنے عورت دوسری عورتوں کے درمیان
# Batch 20 processed. Sample translation:  پگٹیل میں ایک خوش نوجوان لڑکی کچھ دیکھ رہی ہے۔
# Batch 21 processed. Sample translation:  سفید قمیض اور شیشے میں ملبوس ایک آدمی گٹار بجا رہ
# Batch 22 processed. Sample translation:  یہاں ایک کنسرٹ میں رہنے والے پرفارم کرنے والے ایک
# Batch 23 processed. Sample translation:  ایک عورت پھولوں کو پکڑے بازار کے ایک جھانکے کے سا
# Batch 24 processed. Sample translation:  لوگوں کا ایک گروپ عمارت کے اندر کھڑا ہے اور بات ک
# Batch 25 processed. Sample translation:  سفید پوش دو باورچی باورچی خانے میں کام کر رہے ہیں
# Batch 26 processed. Sample translation:  ایک آدمی نیلی جینز پہنے باہر کھڑا ہے اور اس کے سر
# Batch 27 processed. Sample translation:  پیدل چلنے والے اور کاریں نیویارک کے ٹائمز اسکوائر
# Batch 28 processed. Sample translation:  سیاہ پوش دو آدمی برش صاف کر رہے ہیں، ایک کے پاس س
# Batch 29 processed. Sample translation:  آڑو رنگ کی قمیض میں ملبوس آدمی ایک بڑی ٹوکری پر س
# Batch 30 processed. Sample translation:  ایک بوڑھی، سفید فام عورت سوئمنگ سوٹ پہنے ایک ہجوم
# Batch 31 processed. Sample translation:  ایک کتا جو کویووٹ کی طرح نظر آتا ہے ٹینس بال کو پ
# Batch 32 processed. Sample translation:  ایک لڑکی شیطان کا لباس پہنے شہر کی سڑک پر ایک روش
# Batch 33 processed. Sample translation:  ایک چھوٹا بچہ گیند سے کھیلتا ہے جبکہ دوسرے آرام ک
# Batch 34 processed. Sample translation:  ہلکے سبز رنگ کی قمیض میں ملبوس ایک شخص ہلکی سبز گ
# Batch 35 processed. Sample translation:  دو لڑکیاں گرے سویٹ جیکٹس پہنے ایک مصروف سڑک کے کن
# Batch 36 processed. Sample translation:  ایک نوجوان بیل کو ایک آدمی نے سینگوں سے پکڑا ہے ج
# Batch 37 processed. Sample translation:  ایک بوڑھا شریف آدمی ایک بڑی میرون سویٹر بنیان اور
# Batch 38 processed. Sample translation:  نیلے کوٹ والا شخص فرش پر کھڑے پانی میں چھلانگ لگا
# Batch 39 processed. Sample translation:  کمرے کے سامنے نیلی قمیض پہنے ایک آدمی ہے اور کئی
# Batch 40 processed. Sample translation:  رنگین لباس میں ملبوس ایک ایشیائی خاتون ہنس رہی ہے
# Batch 41 processed. Sample translation:  ایک نوجوان ہندوستانی مرد بھوری کرسی کے پاس بلے سے
# Batch 42 processed. Sample translation:  ایک سیاہ بالوں والا بچہ ایک بند دروازے کے سامنے ک
# Batch 43 processed. Sample translation:  گہرے رنگ کی پتلون پہنے تین نوجوان لڑکے ایک ٹریک پ
# Batch 44 processed. Sample translation:  لوگوں کا ایک گروپ، سرخ بالوں والی ایک عورت، کھانے
# Batch 45 processed. Sample translation:  ایک ہجوم ایک راک بینڈ کو اسٹیج پر پرفارم کرتے ہوئ
# Batch 46 processed. Sample translation:  سرخ اور بھوری رنگ کی قمیض پہنے ایک بچہ چاک بورڈ ک
# Batch 47 processed. Sample translation:  ایک چھوٹی بچی پانی کے چشمے میں کھیل رہی ہے، پانی
# Batch 48 processed. Sample translation:  لباس میں خواتین ماسک اور ہیئر نیٹ پہن کر اسمبلی ل
# Batch 49 processed. Sample translation:  سکی ایریا میں دیودار کے درخت اور پس منظر میں ایک
# Batch 50 processed. Sample translation:  ایک آدمی جالیوں سے لدے پہیوں پر ایک گاڑی کھینچ رہ
# Batch 51 processed. Sample translation:  نیلے پانی کے قریب ریتیلے ساحل پر بالغوں اور بچوں
# Batch 52 processed. Sample translation:  سفید ہیلمٹ کے ساتھ نیلے رنگ کا سکوٹر اور دو خواتی
# Batch 53 processed. Sample translation:  گرے ٹینک ٹاپ پہنے ایک سنہرے بالوں والی عورت اپنی
# Batch 54 processed. Sample translation:  سفید لباس میں چھوٹی لڑکی پارک کے بڑے فوارے کے سام
# Batch 55 processed. Sample translation:  ایک ایشیائی لڑکی اور لڑکا سیاہ اور سفید فرش پر پی
# Batch 56 processed. Sample translation:  ایک کسان عورت سڑک پر طرح طرح کی سبزیاں بیچ رہی ہے
# Batch 57 processed. Sample translation:  بھوری رنگ کی جیکٹ پہنے آدمی سبز بینچ پر بیٹھا سرخ
# Batch 58 processed. Sample translation:  گلابی لباس پہنے ایک چھوٹی سی لڑکی ایک آدمی کے پاس
# Batch 59 processed. Sample translation:  کیموفلاج پینٹ اور سفید جھاگ یا کریم میں ڈھکی سیاہ
# Batch 60 processed. Sample translation:  کاروں اور کھڑی موٹرسائیکلوں سے بھری مصروف سڑک کے
# Batch 61 processed. Sample translation:  کھیت میں ایک گہرا بھورا کتا اور ہلکا بھورا کتا ای
# Batch 62 processed. Sample translation:  ایک آدمی جس کے سامنے ایک نشان ہے جس پر لکھا ہے &q
# Batch 63 processed. Sample translation:  ایک شخص دھاری دار اسکرٹ پہنے اور سر کو ڈھانپے ہوئ
# Batch 64 processed. Sample translation:  ایک بچہ ایسا محسوس کرتا ہے جیسے وہ اڑ رہا ہے جب ا
# Batch 65 processed. Sample translation:  سفید لباس اور سر پر پٹی پہنے ایک چھوٹی سی لڑکی جن
# Batch 66 processed. Sample translation:  The Screaming Orphans بینڈ لائیو پرفارم کر رہا ہے
# Batch 67 processed. Sample translation:  سیاہ لباس میں ملبوس ایک آدمی، ایک بڑے خالی ہال می
# Batch 68 processed. Sample translation:  ایک عورت سرخ لباس اور سیاہ ماسک پہنے ہوئے ہے جبکہ
# Batch 69 processed. Sample translation:  دو کتے سائے میں بیٹھ کر ایک دوسرے کا منہ چاٹ رہے
# Batch 70 processed. Sample translation:  ایک آدمی اور ایک گائے کو پیش منظر میں دکھایا گیا
# Batch 71 processed. Sample translation:  دھاری دار قمیض پہنے ایک لڑکے سمیت کئی لوگ پانی کے
# Batch 72 processed. Sample translation:  ایسا لگتا ہے کہ یہ ایک عورت ہے جو ایک بڑی، کائی س
# Batch 73 processed. Sample translation:  یہ لڑکی ایک ایسی چیز پر کھیل رہی ہے جو پیلے، سبز،
# Batch 74 processed. Sample translation:  نیلے کالر پہنے ایک ٹین کتا نارنجی رنگ کے کھلونے س
# Batch 75 processed. Sample translation:  عینک والا ایک بوڑھا آدمی اپنے ہاتھوں کو ایک ساتھ
# Batch 76 processed. Sample translation:  روشن سرخ لپ اسٹک اور بڑے سنہرے بالوں والی ایک عور
# Batch 77 processed. Sample translation:  نارنجی رنگ کی قمیض میں ایک لڑکا، جس کے کندھے پر ن
# Batch 78 processed. Sample translation:  تین خواتین کلاس کے سامنے مارکر بورڈ کے سامنے ہنس
# Batch 79 processed. Sample translation:  ردی کی ٹوکری جمع کرنے والا ایک بڑا بیگ اور صفائی
# Batch 80 processed. Sample translation:  حال ہی میں اپنایا گیا مخلوط نسل کے درمیانے سائز ک
# Batch 81 processed. Sample translation:  نیلی شرٹ اور نیلی جینز میں ایک چھوٹا لڑکا جھولے ک
# Batch 82 processed. Sample translation:  ایک تقریب میں شرکت کے بعد شوہر اور بیوی آرام کر ر
# Batch 83 processed. Sample translation:  رنگین شارٹس پہنے ایک چھوٹا بچہ پانی میں کھڑا ہے۔
# Batch 84 processed. Sample translation:  اورنج واسکٹ پہنے تعمیراتی کارکنوں کا ایک گروپ ٹری
# Batch 85 processed. Sample translation:  ایک چھوٹا بچہ ہے جس کی سرخ قمیض ہے جس میں کھوپڑی
# Batch 86 processed. Sample translation:  پیلی قمیض اور نیلی جینز میں ملبوس ایک بچہ سرخ کھی
# Batch 87 processed. Sample translation:  چھڑی اور داڑھی والا ایک اچھا لباس والا آدمی، پارک
# Batch 88 processed. Sample translation:  چھ نوجوان لڑکے، ایک افریقی امریکن، ایک لاطینی، او
# Batch 89 processed. Sample translation:  لباس پہنے ایک نوجوان لڑکی گریجویشن کیپ اور گاؤن پ
# Batch 90 processed. Sample translation:  کیچڑ بھرے گھاس کے میدان میں تین لڑکے اور ایک لڑکی
# Batch 91 processed. Sample translation:  سرخ ٹینک ٹاپ پہنے ایک عورت کھانا بنا رہی ہے جبکہ
# Batch 92 processed. Sample translation:  &quot;4&quot; جرسی والا ریسنگ ڈاگ &quot;5&quot; ج
# Batch 93 processed. Sample translation:  حملہ آور کتا اس کپڑے کو کاٹ رہا ہے جسے افسر نے پو
# Batch 94 processed. Sample translation:  ایک بچہ بیٹھتا ہے جبکہ دوسرا گھٹنے ٹیکتا ہے جب وہ
# Batch 95 processed. Sample translation:  ایک نوجوان بھورے بالوں والی لڑکی غار میں ایک بڑے
# Batch 96 processed. Sample translation:  ایک مرد اور عورت ایک میز پر ایک نشان کے سامنے بیٹ
# Batch 97 processed. Sample translation:  سفید لباس میں ایک عورت سوٹ میں ایک آدمی کو اپنے ہ
# Batch 98 processed. Sample translation:  ایک سیلو پلیئر جو فلپ فلاپ پہنے ہوئے ہے اور ایک ن
# Batch 99 processed. Sample translation:  ایک آدمی کچھ لکھ رہا ہے اور باہر نوجوانوں کے ایک
# Batch 100 processed. Sample translation:  سرخ اور سفید گاؤن پہنے ایک عورت نے اپنے پیچھے ایک
# Batch 101 processed. Sample translation:  شیف کی وردی میں ایک آدمی چولہے کے اوپر ایک بڑا پی
# Batch 102 processed. Sample translation:  پیلے رنگ کی قمیض والی عورت دھوپ کا چشمہ پہنتی ہے
# Batch 103 processed. Sample translation:  ایک سیاہ اور سفید شارٹ بال کتا بھوری اور سبز گھاس
# Batch 104 processed. Sample translation:  دو لڑکیاں ساحل سمندر پر گولے تلاش کر رہی ہیں، ایک
# Batch 105 processed. Sample translation:  بھوری رنگ میں ایک گنجا آدمی چھڑی پکڑے ہوئے ہے جب
# Batch 106 processed. Sample translation:  ایک گانے کا گروپ ایک اعلی درجے کی تقریب میں گانا
# Batch 107 processed. Sample translation:  تین افراد، سفید پوش ایک بالغ ایشیائی، سبز رنگ میں
# Batch 108 processed. Sample translation:  جینز میں ملبوس ایک آدمی مصروف فٹ پاتھ اور ہجوم وا
# Batch 109 processed. Sample translation:  ریت میں دوڑتا ہوا کتا، پس منظر میں گھاس۔
# Batch 110 processed. Sample translation:  ایک لڑکا سرخ تیراکی کے تنوں پہنے ساحل سمندر پر پا
# Batch 111 processed. Sample translation:  نیلی قمیض میں ایک گنجا آدمی کھڑکی کو دھو رہا ہے۔
# Batch 112 processed. Sample translation:  لوگ دو لمبی میزوں پر بیٹھے ہیں، ایک کے پیچھے، مشر
# Batch 113 processed. Sample translation:  والدین اور بچے گیمز کے لیے فلی مارکیٹ میں خریداری
# Batch 114 processed. Sample translation:  تین دوست 2008 کے سمر اولمپکس کے باہر تصویر کے لیے
# Batch 115 processed. Sample translation:  ہوا میں پانی کی پگڈنڈی چھوڑ کر دو لوگ نیلی جیٹ سک
# Batch 116 processed. Sample translation:  دو آدمی، دونوں ہیلمٹ پہنے ہوئے، بڑے پہیوں والے سک
# Batch 117 processed. Sample translation:  ہیلمٹ کے ساتھ بائیکر سبز رنگ کی گندگی والی موٹر س
# Batch 118 processed. Sample translation:  جس میں بچے ایک ابتدائی اسکول کے کلاس روم میں کام
# Batch 119 processed. Sample translation:  2 آدمی عمارت کی چھت صاف کرنے کا کام کر رہے ہیں او
# Batch 120 processed. Sample translation:  ریڈ فائر ہائیڈرنٹ پر دو کتے پیشاب کر رہے ہیں۔
# Batch 121 processed. Sample translation:  گرے ٹی شرٹ میں لوگوں کا ایک گروپ سامان کی پلاسٹک
# Batch 122 processed. Sample translation:  ایک بھورے رنگ کا گھوڑا جس پر سوار بیٹھا ہے نیلے ر
# Batch 123 processed. Sample translation:  دو خواتین پیلے رنگ کے دروازوں والے کیفے کے پاس سے
# Batch 124 processed. Sample translation:  پیلے رنگ کی قمیض اور نارنجی پینٹ میں گنجا لڑکا، گ
# Batch 125 processed. Sample translation:  سیگ وے کے ذاتی نقل و حمل کے آلے پر پولیس کی وردی
# Batch 126 processed. Sample translation:  ایک آدمی اپنی سائیکل لے کر ایک چھوٹے سے نشان پر چ
# Batch 127 processed. Sample translation:  فوجی کیموفلاج گیئر میں ایک شخص سرخ، نیلے اور پیلے
# Batch 128 processed. Sample translation:  ایک بھورے رنگ کا کتا گھاس پر اس کے لیے بہت بڑی چھ
# Batch 129 processed. Sample translation:  ایک ایشیائی بچہ اونچی کرسی پر بیٹھا ہے اور ریستور
# Batch 130 processed. Sample translation:  ایک لڑکا اور لڑکی ایک کھیل کے میدان اور پودوں کے
# Batch 131 processed. Sample translation:  ایک چھوٹی سی لڑکی سوئمنگ سوٹ میں ساحل سمندر پر پا
# Batch 132 processed. Sample translation:  ایک پیانوادک دیکھ رہا ہے کہ وہ بجا رہا ہے اور سبز
# Batch 133 processed. Sample translation:  لڑکی کے پاس بیٹھا چھوٹا لڑکا اپنے ہاتھ سے چہرہ ڈھ
# Batch 134 processed. Sample translation:  ایک کانفرنس منعقد کی جا رہی ہے جس میں لیپ ٹاپ اور
# Batch 135 processed. Sample translation:  ایشیا میں کاروباری لباس میں ایک بوڑھا آدمی ٹیکسی
# Batch 136 processed. Sample translation:  ہاکی کے دو کھلاڑی برف پر ایک دوسرے میں پھسل رہے ہ
# Batch 137 processed. Sample translation:  نیلی جینز پہنے ایک افریقی شخص نے دو لڑکوں کا ہاتھ
# Batch 138 processed. Sample translation:  کئی لوگ ایک پل کے کنارے ٹیک لگائے پانی میں نیچے د
# Batch 139 processed. Sample translation:  لمبے بھورے بالوں والی اور سیاہ ایتھلیٹک لباس میں
# Batch 140 processed. Sample translation:  لوگ ایک مصروف فٹ پاتھ پر گھومتے پھرتے ہیں جب ایک
# Batch 141 processed. Sample translation:  ایک سیاہ اور سفید کتا چبانے یا کھیلنے کے لیے اپنے
# Batch 142 processed. Sample translation:  ایک آدمی بغیر ہاتھ کے اپنی BMX سبز سائیکل پر سٹاپ
# Batch 143 processed. Sample translation:  ایک نوجوان لڑکا ناقابل یقین ہلک دستانے کے ساتھ پو
# Batch 144 processed. Sample translation:  سیاہ لباس میں سرخ بالوں والی عورت نے سفید پوش مرد
# Batch 145 processed. Sample translation:  ایک کالا کتا ساحل سمندر پر لہروں کے سامنے اپنے آپ
# Batch 146 processed. Sample translation:  دو آدمی رنگ برنگے ڈبوں میں جادو کرتے ہوئے کھڑے ہی
# Batch 147 processed. Sample translation:  ایک سنو بورڈر رات کے وقت گریفٹی سے ڈھکی دیوار سے
# Batch 148 processed. Sample translation:  کالی دھاریوں والی سرخ جیکٹ پہنے ایک چھوٹا بچہ سات
# Batch 149 processed. Sample translation:  ٹینس کھلاڑی نے گیند وصول کی، اور ایسا کرتے ہوئے ا
# Batch 150 processed. Sample translation:  پتھریلے خطوں اور پانی سے گھری ہوئی گودی پر کشتی ک
# Batch 151 processed. Sample translation:  احتجاج میں سرخ ٹوپی اور نیلی جیکٹ میں ملبوس ایک ش
# Batch 152 processed. Sample translation:  نوجوانوں کی ایک تینوں مائیکروفون کے ساتھ گانا گا
# Batch 153 processed. Sample translation:  لوگوں کا ایک گروپ اپنے ہاتھوں کو ہوا میں اٹھائے ہ
# Batch 154 processed. Sample translation:  کافی پیتے ہوئے اور مفنز کھاتے ہوئے ایک آدمی اپنے
# Batch 155 processed. Sample translation:  بھوری جیکٹ میں ایک بچے سمیت متعدد لوگ، سفید لیب ک
# Batch 156 processed. Sample translation:  روشن رنگ کی قمیض کے ساتھ ایک ایکارڈین کھلاڑی باہر
# Batch 157 processed. Sample translation:  دو نوجوان بالغ کسی کارروائی کے لیے ویڈیو کیمرہ تر
# Batch 158 processed. Sample translation:  ایک کتا لمبے اور چھوٹی گھاس میں غوطہ لگاتے ہوئے ب
# Batch 159 processed. Sample translation:  نیلی نیل پالش والی لڑکی، ورکشاپ یا گیراج میں مختل
# Batch 160 processed. Sample translation:  نیلے رنگ کی باسکٹ بال جرسی پہنے ایک آدمی باسکٹ با
# Batch 161 processed. Sample translation:  ایک چھوٹی نسل کا کتا بھوسے والے کھیت میں دوڑ رہا
# Batch 162 processed. Sample translation:  ایک سرخ بالوں والا آدمی سوٹ پہنے باہر نکلنے کے در
# Batch 163 processed. Sample translation:  سرخ کالر پہنے ایک کالا کتا لکڑی کی باڑ کے پاس برف
# Batch 164 processed. Sample translation:  سفید ٹوپی اور ٹینک ٹاپ پہنے ایک سیاہ فام آدمی دوس
# Batch 165 processed. Sample translation:  چار لوگ ایک دوسرے کے کندھے سے کندھے پکڑے ایک بھور
# Batch 166 processed. Sample translation:  اسکیٹ بورڈر اسکیٹ پارک میں نائٹ اسکیٹنگ سے لطف ان
# Batch 167 processed. Sample translation:  کالی ٹی شرٹ اور شیشے میں ملبوس ایک مرد اپنے کام ک
# Batch 168 processed. Sample translation:  ایشیائی زبان میں لکھے ہوئے نشان کے سامنے نیلی قمی
# Batch 169 processed. Sample translation:  بڑا بھورا کتا باہر گندگی میں بھاگ رہا ہے۔
# Batch 170 processed. Sample translation:  ایک مسکراتی ہوئی پولیس خاتون جس نے نیلی کلہاڑی پک
# Batch 171 processed. Sample translation:  ایک چھوٹا بچہ سیلون میں اپنے بال کٹوا رہا ہے۔
# Batch 172 processed. Sample translation:  دو آدمی پائیک پلیس مارکیٹ کے قریب کھڑے ہیں جبکہ پ
# Batch 173 processed. Sample translation:  ایک جیولوجیکل فارمیشن کے قریب فولڈ ایبل کرسیوں پر
# Batch 174 processed. Sample translation:  ایک آدمی ایک تختے پر پانی پر سوار ہے، ایک ہاتھ سے
# Batch 175 processed. Sample translation:  گہرے رنگ کی پینٹ اور سبز ٹی شرٹ میں ایک لڑکا ریمپ
# Batch 176 processed. Sample translation:  دو آدمی دفتر کے آرام دہ ماحول میں ہیں اور وہ دونو
# Batch 177 processed. Sample translation:  ایک آدمی عمارتوں کے درمیان کھڑے نیلے رنگ کے ایک ب
# Batch 178 processed. Sample translation:  نیلے تہبند میں بوڑھی عورت سیاہ لباس میں ملبوس ایک
# Batch 179 processed. Sample translation:  سیاہ اور سفید پیارے کتے گھاس والے علاقے میں ایک ک
# Batch 180 processed. Sample translation:  بحریہ کے نیلے رنگ کے سویٹ سوٹ میں ایک عورت اپنے س
# Batch 181 processed. Sample translation:  سبز قمیض کے ساتھ ایک پسینے میں شرابور سیاہ آدمی ک
# Batch 182 processed. Sample translation:  بچوں کا ایک گروپ ایک آدمی کو دیکھ رہا ہے جو اپنی
# Batch 183 processed. Sample translation:  چھوٹے بالوں اور کالی ٹی شرٹ والی عورت ایک پرہجوم
# Batch 184 processed. Sample translation:  ایک کالا کتا سفید قالین پر نیلی گڑیا کے ساتھ کھیل
# Batch 185 processed. Sample translation:  ایلمو ٹی شرٹ پہنے نوجوان لڑکا اپنے کھانے کے ساتھ
# Batch 186 processed. Sample translation:  کئی لوگ ایک لمبی گلی سے گزرتے ہوئے ایک کھڑی موٹر
# Batch 187 processed. Sample translation:  ایک آدمی ایک میز پر کھا رہا ہے، آلو کی اکیلی چپس
# Batch 188 processed. Sample translation:  ایک آدمی زیر تعمیر عمارت کے سامنے سڑک کے پار بھاگ
# Batch 189 processed. Sample translation:  دو کتے، ایک بھورا ایک سیاہ پیلے کھلونا کے ساتھ، ک
# Batch 190 processed. Sample translation:  ایک سخت ٹوپی اور نیلی جین اوورلز میں ملبوس ایک آد
# Batch 191 processed. Sample translation:  ہوا میں چار پہیوں والی موٹر سائیکل پر ہیلمٹ پہنے
# Batch 192 processed. Sample translation:  ایک کتا گھاس میں چھڑکاؤ کے ذریعے بھاگ رہا ہے۔
# Batch 193 processed. Sample translation:  فیڈورا کے ساتھ ایک چھوٹے آدمی کے منہ میں دو خالی
# Batch 194 processed. Sample translation:  پرفیکٹ فیگرز والی بیکنی پہنے دو نوجوان لڑکیاں ساح
# Batch 195 processed. Sample translation:  گلابی کوٹ میں دو لڑکیاں سوڈا کی بوتلوں سے پی رہی
# Batch 196 processed. Sample translation:  سرخ اور سفید کپڑوں میں ملبوس چیئر لیڈرز اپنے بالو
# Batch 197 processed. Sample translation:  چار لوگوں کا ایک گروپ کیمرے سے دور بھاگ رہا ہے، ا
# Batch 198 processed. Sample translation:  ٹوپی پہنے ایک چھوٹا لڑکا ساحل سمندر پر گیلی ریت م
# Batch 199 processed. Sample translation:  سرخ اور سفید کینیڈین وردی پہنے ایک آدمی میدان میں
# Batch 200 processed. Sample translation:  ہوائی جہاز پر ایک بنڈاری ایک کارٹ کو مرکز کے جزیر
# Batch 201 processed. Sample translation:  ایک آدمی پتھروں کے اوپر اور پانی کی طرف کود رہا ہ
# Batch 202 processed. Sample translation:  شارٹس اور ٹی شرٹ میں ملبوس ایک نوجوان لڑکی ایک چھ
# Batch 203 processed. Sample translation:  گلابی کھانے کی ٹرے کے سامنے ایک چھوٹی لڑکی کو ایک
# Batch 204 processed. Sample translation:  ایک ادھیڑ عمر کا آدمی، جس کے پاس کالی قمیض ہے جس
# Batch 205 processed. Sample translation:  ایک عورت جزوی طور پر ابر آلود آسمان کے سائے میں چ
# Batch 206 processed. Sample translation:  ایک گول میز پر بیٹھے تین لوگ دیوار پر لکھی ہوئی ک
# Batch 207 processed. Sample translation:  اسنو بورڈنگ کرنے والا ایک شخص پہاڑی سے نیچے جانے
# Batch 208 processed. Sample translation:  رنگین لباس پہنے ہوئے، لمبے بالوں والی خواتین اور
# Batch 209 processed. Sample translation:  ایک مرد اور ایک عورت ایک کار کے پاس سے گزر رہے ہی
# Batch 210 processed. Sample translation:  پیلے اور کالے سوٹ میں ملبوس 5 آدمی ایک ٹرک کے پاس
# Batch 211 processed. Sample translation:  اوپر سے ایک عورت کو اپنے پیروں پر سرخ نیل پالش لگ
# Batch 212 processed. Sample translation:  پس منظر میں فیرس وہیل کے ساتھ مصروف ساحل پر ایک ش
# Batch 213 processed. Sample translation:  ایک اسکیئر اپنی پیٹھ پر لیٹا ہوا ہے، بازو پھیلائے
# Batch 214 processed. Sample translation:  ایک شکل ٹین کی چھت والے ڈھانچے کے سامنے کھڑی ہے ج
# Batch 215 processed. Sample translation:  ہلکی نیلی قمیض، نیلی جینز اور رولر بلیڈ والا لڑکا
# Batch 216 processed. Sample translation:  دو لوگ دو پہاڑوں کے درمیان ایک کھڑی، پتھریلی پگڈن
# Batch 217 processed. Sample translation:  دو افراد، ایک سبز قمیض میں اور ایک سرخ قمیض میں،
# Batch 218 processed. Sample translation:  بغیر قمیض اور جامنی رنگ کی پینٹ والا آدمی کسی دھا
# Batch 219 processed. Sample translation:  دو لڑکیاں، ایک نے گلابی قمیض پہنی ہوئی ہے اور دوس
# Batch 220 processed. Sample translation:  ایک عورت سماجی ماحول میں بیئر پی رہی ہے، ایک مرد
# Batch 221 processed. Sample translation:  motocross میں ایک وردی پوش حریف نے کورس میں ایک چ
# Batch 222 processed. Sample translation:  ایک کارکن پلیٹ فارم پر کھڑا، زمین کے اوپر لٹکا ہو
# Batch 223 processed. Sample translation:  دھاری دار پتلون اور سرسوں کی پیلی قمیض میں آدمی ا
# Batch 224 processed. Sample translation:  بھورے رنگ کی قمیض میں ملبوس ایک نوجوان کھانے کی پ
# Batch 225 processed. Sample translation:  باہر لوگوں کا ایک گروپ ڈھول بجا رہا ہے اور کالے ا
# Batch 226 processed. Sample translation:  گلابی قمیض میں ملبوس ایک آدمی لیپ ٹاپ کمپیوٹر کی
# Batch 227 processed. Sample translation:  پیلے رنگ کی حفاظتی بنیان پہنے ایک آدمی مشینری پر
# Batch 228 processed. Sample translation:  کنونشن کی تقریب کے لیے ایک نوجوان خاتون گوتھک لول
# Batch 229 processed. Sample translation:  تھائی لینڈ میں ایک انتہائی سجا ہوا آدمی رنگین لبا
# Batch 230 processed. Sample translation:  ایک سنہرے بالوں والی عورت بھورے چمڑے کی کرسی پر ب
# Batch 231 processed. Sample translation:  سیاہ بالوں والی دو خواتین چھتریوں کو پکڑے طوفان ک
# Batch 232 processed. Sample translation:  ایک تہوار جس میں چینی یا جاپانی لوگ سڑک پر ایک بڑ
# Batch 233 processed. Sample translation:  داڑھی میں چھوٹے بھورے بالوں والا ایک گوشت دار لڑک
# Batch 234 processed. Sample translation:  دو بچے جیک او لالٹین کے ساتھ پوز دے رہے ہیں جو ان
# Batch 235 processed. Sample translation:  کوٹ میں ایک شخص سڑک کے لیمپ کی روشنی سے برف میں س
# Batch 236 processed. Sample translation:  نیم ابر آلود دن میں ایک وسیع کھلی جگہ پر دو لوگ س
# Batch 237 processed. Sample translation:  ایک آدمی چھت کے سوراخ سے سیڑھی پر سر رکھ کر کھڑا
# Batch 238 processed. Sample translation:  لمبی بازو، نیلی پلیڈ شرٹ اور ٹین پینٹ پہنے ایک آد
# Batch 239 processed. Sample translation:  ایک عورت پس منظر میں گتے کے ساتھ ایک دراز بنا رہی
# Batch 240 processed. Sample translation:  چرواہا ٹوپیاں پہنے ہوئے 3 ادھیڑ عمر کے مرد تار کی
# Batch 241 processed. Sample translation:  دو مسکراتے ہوئے آدمی، ایک نے سرخ جیکٹ پہنی ہوئی ہ
# Batch 242 processed. Sample translation:  سفید ٹوپی اور نیلی قمیض میں ایک آدمی گڑیا کے پرزو
# Batch 243 processed. Sample translation:  ایک بزرگ جو نیلی قمیض پہنے ہوئے ہیں پہاڑوں کی تصو
# Batch 244 processed. Sample translation:  کئی لوگ ایک مائیکروفون کے ذریعے ایک اسٹیج پر ہیں۔
# Batch 245 processed. Sample translation:  یہاں ایک عورت اور اس کے شوہر اور بچے کی پارکنگ می
# Batch 246 processed. Sample translation:  ایک سنہرے بالوں والی، سفید رنگ کی جلد والا بچہ گل
# Batch 247 processed. Sample translation:  جامنی رنگ کی ایک بڑی ٹوپی اور نیلے رنگ کے لمبے کو
# Batch 248 processed. Sample translation:  سبز رنگ کا کوٹ پہنے نینسی پیلوسی نوجوانوں کے ہجوم
# Batch 249 processed. Sample translation:  ایک نر اور مادہ ہاتھ پکڑے ہوئے ہیں اور دھوپ والے
# Batch 250 processed. Sample translation:  سفید شرٹ اور نارنجی رنگ کی قمیض پہنے ایک شخص ہوا
# Batch 251 processed. Sample translation:  دو لوگ ایک گرم سرکلر گرل اور انڈوں کی ٹوکری کے سا
# Batch 252 processed. Sample translation:  کاریں پل کے نیچے چلتی ہیں جبکہ لوگ اوپر چلتے ہیں۔
# Batch 253 processed. Sample translation:  سبزی منڈی میں کالی جیکٹ پہنے ایک عورت اپنے کالے پ
# Batch 254 processed. Sample translation:  ایک بوڑھا آدمی شاپنگ بیگ اٹھائے فٹ پاتھ پر چل رہا
# Batch 255 processed. Sample translation:  دو آدمی گٹار کے ساتھ اور ایک مائیکروفون کے ساتھ ل
# Batch 256 processed. Sample translation:  سبز پھولوں سے بھرا ہوا ایک سرخ پھولوں کا ڈبہ ایک
# Batch 257 processed. Sample translation:  ایک پلاٹینم سنہرے بالوں والی نوجوان عورت جو بھاری
# Batch 258 processed. Sample translation:  ایک ردی کی ٹوکری والا آدمی اپنی گاڑی کو ایک نشان
# Batch 259 processed. Sample translation:  لوگ یہ بتانے کی کوشش کرتے ہیں کہ کس طرح بڑی کمپنی
# Batch 260 processed. Sample translation:  سرخ اور سیاہ دھاری دار لباس پہنے ایک عورت فٹ پاتھ
# Batch 261 processed. Sample translation:  تین شریف آدمی، ایک بینچ پر بیٹھا ہے اور دو دیوار
# Batch 262 processed. Sample translation:  تقریباً بادل کے بغیر تین خواتین کنکریٹ کے ڈھانچے
# Batch 263 processed. Sample translation:  لوگوں کا ایک بڑا گروپ رات کے وقت بازار میں خریدار
# Batch 264 processed. Sample translation:  پیش منظر میں دو لوگ رات کے وقت کاروبار کے نیین عل
# Batch 265 processed. Sample translation:  لوگوں کو شہر کی ایک عجیب و غریب سڑک پر چلتے ہوئے
# Batch 266 processed. Sample translation:  نیلی قمیض اور سیاہ جیکٹ میں ایک سفید آدمی باہر کھ
# Batch 267 processed. Sample translation:  چھوٹا بچہ ایک چمچ پکڑے مسکرا رہا ہے، میز پر بیٹھا
# Batch 268 processed. Sample translation:  بھورے بال، کالی جیکٹ، بڑے سیاہ چشمے اور گلابی اسک
# Batch 269 processed. Sample translation:  ایک عورت جس کا چہرہ پینٹ کیا گیا ہے وہ چاندی کے ب
# Batch 270 processed. Sample translation:  ایک سویٹر اور جینز پہنے ایک عورت ایک آؤٹ ڈور پارک
# Batch 271 processed. Sample translation:  بنیان میں ملبوس ایک آدمی بائنڈر پکڑے سڑک پر چل رہ
# Batch 272 processed. Sample translation:  نیلی ہارلے موٹرسائیکل موٹرسائیکلوں کے گروپ میں سے
# Batch 273 processed. Sample translation:  بیکنی میں ملبوس ایک عورت کیمرے کی طرف دیکھتی ہے ا
# Batch 274 processed. Sample translation:  نوجوان خواتین اپنے کمپیوٹر پر کام کر رہی ہیں، ایک
# Batch 275 processed. Sample translation:  لوگوں کا ایک گروپ پانی کے صاف جسم کے پاس کچھ چٹان
# Batch 276 processed. Sample translation:  آدمی ساحل سمندر پر ننگے پاؤں چہل قدمی کر رہا ہے ج
# Batch 277 processed. Sample translation:  لوگوں کا ایک بہت بڑا مجمع ہے جس میں دو آدمی سفید
# Batch 278 processed. Sample translation:  کالی شرٹ والی عورت بھری گلی کے درمیان اپنی موٹر س
# Batch 279 processed. Sample translation:  ایک اکیلی عورت ایک بڑی سفید عمارت کے سامنے چل رہی
# Batch 280 processed. Sample translation:  ایک آدمی جس کے سر کے اوپر دھوپ کا چشمہ ہے ایک سلا
# Batch 281 processed. Sample translation:  سفید بکنی میں ملبوس ایک عورت ساحل سمندر پر کھڑی ہ
# Batch 282 processed. Sample translation:  سیاہ پتلون، دھوپ اور سیاہ اور سفید ٹینک ٹاپ میں ا
# Batch 283 processed. Sample translation:  اے ٹیم فلم کے نشان کے ساتھ ایک شخص بس اسٹاپ بینچ
# Batch 284 processed. Sample translation:  کاروباری لباس میں دو مرد اور دو خواتین پبلک ٹرانس
# Batch 285 processed. Sample translation:  ایک نیلے رنگ کی کشتی سرخ، نارنجی اور سفید گھروں س
# Batch 286 processed. Sample translation:  سرخ اور نیلے کالر والا بھورا اور سیاہ کتا بھوری گ
# Batch 287 processed. Sample translation:  سرخ اور سنہری یونیفارم پہنے دو خواتین ڈریگن کو پک
# Batch 288 processed. Sample translation:  سرمئی بالوں والی ایک عورت ایک چھوٹے لڑکے کے پاس ب
# Batch 289 processed. Sample translation:  نارنجی اور سفید لباس میں ایک لڑکی تربیتی پہیوں کے
# Batch 290 processed. Sample translation:  سنہرے بالوں والی ایک عورت، سفید قمیض پہنے دوسرے ل
# Batch 291 processed. Sample translation:  بہت سے لوگ ان دیواروں کو دیکھتے ہیں جو مختلف تھیم
# Batch 292 processed. Sample translation:  سیاہ ٹینک ٹاپ اور سرمئی کیپری پینٹ میں ایک لڑکی س
# Batch 293 processed. Sample translation:  ہیلمٹ پہنے ایک لڑکا مضافاتی محلے میں سکوٹر چلا رہ
# Batch 294 processed. Sample translation:  ایک رکاوٹ دو خواتین اور تین بچوں کو مردوں کے ایک
# Batch 295 processed. Sample translation:  ایک بوڑھا آدمی ایک بڑی ٹوپی پہنے، اور موٹر والی و
# Batch 296 processed. Sample translation:  دو خواتین ایک ایشیائی سجاوٹ کو دیکھ رہی ہیں جو ای
# Batch 297 processed. Sample translation:  8 تعمیراتی کارکن ہوا میں بلندی پر سہاریں لگا رہے
# Batch 298 processed. Sample translation:  سفید قمیض اور کالی پینٹ میں ایک آدمی نے ایک بچے ک
# Batch 299 processed. Sample translation:  سفید ٹوپی اور قمیض میں ملبوس ایک آدمی سڑک کے دوسر
# Batch 300 processed. Sample translation:  ایک سرمئی بالوں والا، داڑھی والا آدمی ایک آؤٹ ڈور
# Batch 301 processed. Sample translation:  کچھ مرد پھلوں اور سبزیوں کی ٹوکری کے ساتھ دائرے م
# Batch 302 processed. Sample translation:  کالے کوٹ، نیلی جینز اور دھوپ کے چشموں میں ایک گھٹ
# Batch 303 processed. Sample translation:  لمبے بالوں والا ایک سفید کتا سرخ اور سبز کھلونا ک
# Batch 304 processed. Sample translation:  نیلے اور سیاہ پلیڈ اوور شرٹ پہنے ایک آدمی سرمئی پ
# Batch 305 processed. Sample translation:  لوگوں کا ایک گروپ بس اسٹاپ کے ساتھ والی عمارت کے
# Batch 306 processed. Sample translation:  دو ادھیڑ عمر سفید فام خواتین سائیکلوں کے مجموعے ک
# Batch 307 processed. Sample translation:  پھولوں کے سامنے بیٹھی ایک نوجوان عورت اپنے مشروب
# Batch 308 processed. Sample translation:  ایک مسکراتی ہوئی لڑکی نے ایک سفید چھتری پکڑی ہوئی
# Batch 309 processed. Sample translation:  بہت سے لوگ شہر کے باہر حفاظتی واسکٹ پہنے ہوئے گھو
# Batch 310 processed. Sample translation:  ایک آدمی ایک باغ میں لان کی کٹائی کر رہا ہے، اس ک
# Batch 311 processed. Sample translation:  گلابی چشمیں پہنے ایک لڑکی پانی کے اندر ہے کیونکہ
# Batch 312 processed. Sample translation:  لوگ کالموں والی سفید عمارت کے باہر لکڑی کے بنچوں
# Batch 313 processed. Sample translation:  کالی قمیضوں میں ملبوس دو لڑکے براؤن چمڑے کی جیکٹ
# Batch 314 processed. Sample translation:  قدیم عمارت کے ساتھ ساتھ چلتے ہوئے ایک آدمی بہت چھ
# Batch 315 processed. Sample translation:  کئی لوگ والی بال کھیل رہے ہیں جس کے پس منظر میں &
# Batch 316 processed. Sample translation:  کالی ایڑیوں والی ایک عورت بڑی ہوپ بالیاں پہنے دوس
# Batch 317 processed. Sample translation:  سالمن اسکرٹ میں ایک چھوٹی سی لڑکی فٹ بال کی گیند
# Batch 318 processed. Sample translation:  ایک عورت ہنگامی دروازے کے سامنے زمین پر بیٹھ کر ک
# Batch 319 processed. Sample translation:  لمبی عمودی کھڑکیوں والی سرخ اینٹوں کی عمارت کے سا
# Batch 320 processed. Sample translation:  کالی پینٹ اور کالی ٹی میں ایک آدمی ٹرک کے سامنے ا
# Batch 321 processed. Sample translation:  لال فائر ٹرک جس پر روشنیاں جل رہی ہیں اور قریب کھ
# Batch 322 processed. Sample translation:  سرمئی رنگ کا سویٹر پہنے ایک عورت گلی میں سبز کھمب
# Batch 323 processed. Sample translation:  ٹین اسکرٹ پہنے ایک عورت ایک بہت بڑی عمارت کے سامن
# Batch 324 processed. Sample translation:  دو لڑکیوں نے اپنی تصویر ایک غیر معمولی زاویے سے ل
# Batch 325 processed. Sample translation:  دو لڑکے ایک تالاب میں پانی کے اندر تیر رہے ہیں او
# Batch 326 processed. Sample translation:  ایک سامعین دیکھ رہا ہے کہ ایک بڑا آدمی ربڑ کے مال
# Batch 327 processed. Sample translation:  ایک مصروف پھولوں کی دکان میں کام کرنے والے ملازمی
# Batch 328 processed. Sample translation:  قالین والے فرش پر ایک سیاہ کتے نارنجی کے ساتھ کھی
# Batch 329 processed. Sample translation:  ایک پولیس افسر اپنی موٹرسائیکل کے ساتھ دو فوجی اف
# Batch 330 processed. Sample translation:  پیلے رنگ کی قمیض پہنے ایک نوجوان لڑکی نے اپنے گال
# Batch 331 processed. Sample translation:  دو خواتین، ایک سفید اور کالے ٹینک میں گھاس میں لو
# Batch 332 processed. Sample translation:  ایک سفید کتے ایک سفید دیوار کے ساتھ لگے نل سے پان
# Batch 333 processed. Sample translation:  دو گھوڑے اور آدمی سردی کے دن برف میں سے گزر رہے ہ
# Batch 334 processed. Sample translation:  ایک آدمی سڑک کے کنارے ایک کار سے ہوا میں چھلانگ ل
# Batch 335 processed. Sample translation:  ایک سیاہ پوش عورت شہری فٹ پاتھ پر ایک نارنجی رنگ
# Batch 336 processed. Sample translation:  سرخ ساکر سوٹ والا لڑکا نیچے گر رہا ہے جبکہ سفید ش
# Batch 337 processed. Sample translation:  ایک فائر ٹرک ایک پل پر رک کر کال کرتا ہے، جہاں ای
# Batch 338 processed. Sample translation:  ایک نوجوان لڑکا جو 20 کے اواخر یا 30 کی دہائی کے
# Batch 339 processed. Sample translation:  کالی شارٹس اور نیلی قمیض پہنے ہوئے ایک نوجوان کا
# Batch 340 processed. Sample translation:  ایک جوڑا مسکراتے ہوئے، ایک تقریب میں دوسرے بالغوں
# Batch 341 processed. Sample translation:  میوزیکل ٹیٹو اور کالی قمیض والا ایک نوجوان کھلے م
# Batch 342 processed. Sample translation:  آرٹ گیلری میں ایک عورت تین پورٹریٹ کے درمیان کے ا
# Batch 343 processed. Sample translation:  پیلے رنگ کی قمیض پہنے ایک آدمی اپنی سائیکل پر کچھ
# Batch 344 processed. Sample translation:  ایک متجسس عورت دوسری عورت اپنا سیل فون استعمال کر
# Batch 345 processed. Sample translation:  تین لڑکے، ایک چھوٹی کشتی کے سرے پر بیٹھے ہوئے اور
# Batch 346 processed. Sample translation:  لگ بھگ سات بالغ اور ایک بچہ کھانے پینے کی پلیٹوں
# Batch 347 processed. Sample translation:  ایک سرخ بالوں والی عورت پھلوں کے کپ بیچ رہی ہے، ج
# Batch 348 processed. Sample translation:  ایک نوجوان عورت، کالا کوٹ پہنے اور گود میں کتاب ل
# Batch 349 processed. Sample translation:  کالی ٹی شرٹ پہنے ایک نوجوان زمین سے تقریباً چار ف
# Batch 350 processed. Sample translation:  ایک پلیڈ شرٹ میں ایک عورت کھانے کے ڈبے کو دیکھ رہ
# Batch 351 processed. Sample translation:  پیلے رنگ کی قمیض اور پیلے رنگ کے ہیلمٹ میں ملبوس
# Batch 352 processed. Sample translation:  کالج کا ایک طالب علم ایک کرسی پر بیٹھا ایک گندے چ
# Batch 353 processed. Sample translation:  لوگ سفید لباس اور سرخ پٹی میں ملبوس لڑکی کو سیڑھی
# Batch 354 processed. Sample translation:  دو لائن مین کے درمیان ایک دوڑتے ہوئے پیچھے ہٹنے و
# Batch 355 processed. Sample translation:  ریسنگ سوٹ میں ملبوس آدمی، اسفالٹ ٹریک پر موٹر سائ
# Batch 356 processed. Sample translation:  ایک لڑکی، سرخ رنگ کا اسکرٹ اور کالی قمیض پہنے، گھ
# Batch 357 processed. Sample translation:  بیک بیگ، شارٹس، ٹی شرٹ، سینڈل اور ٹوپی پہنے تین ن
# Batch 358 processed. Sample translation:  قمیض کے بغیر نوجوان چٹان کے چہرے پر چڑھتا ہوا اگل
# Batch 359 processed. Sample translation:  ان لائن اسکیٹر لڑکا، نارنجی قمیض میں، نیلے بیرل پ
# Batch 360 processed. Sample translation:  ایک لڑکا پہاڑی اور جنگل والے علاقے میں سنو بورڈنگ
# Batch 361 processed. Sample translation:  ایک بوڑھا آدمی جو اپنی ساٹھ سال کی عمر کا معلوم ہ
# Batch 362 processed. Sample translation:  تین چھوٹی لڑکیاں کھڑکی سے برفانی منظر کا مشاہدہ ک
# Batch 363 processed. Sample translation:  دو افریقی لڑکے ایک جھونپڑی کے سامنے ایک دوسرے کو
# Batch 364 processed. Sample translation:  ہر عمر اور پس منظر کی خواتین انڈور اسٹوڈیو میں یو
# Batch 365 processed. Sample translation:  پلیڈ قمیض پہنے ہوئے قریب سے کٹے ہوئے بالوں والا ا
# Batch 366 processed. Sample translation:  ایک بیٹھا ہوا آدمی اپنا منہ ڈھانپ رہا ہے، فٹ پاتھ
# Batch 367 processed. Sample translation:  تین آدمی باہر تشریف لا رہے ہیں، ان میں سے ایک کی
# Batch 368 processed. Sample translation:  ایک نوجوان لڑکا، کاؤ بوائے کے لباس میں ملبوس، سرپ
# Batch 369 processed. Sample translation:  تین آدمی نیلے رنگ کے جہاز کے عرشے پر کھڑے ہیں، دو
# Batch 370 processed. Sample translation:  شیشے والی اور لباس پہنے ایک عورت پودے کے سامنے صو
# Batch 371 processed. Sample translation:  سائنس ٹیلنٹ شو کے دوران سائنس پروجیکٹ پر کام کرنے
# Batch 372 processed. Sample translation:  ایک اسٹیج پر نوجوان مردوں اور عورتوں کا گروپ گانا
# Batch 373 processed. Sample translation:  گھوڑوں پر سوار کئی لوگ کہیں جانے کی جلدی میں ہیں۔
# Batch 374 processed. Sample translation:  کئی مرد چیئر لیڈرز کئی خواتین چیئر لیڈرز کو ایک ٹ
# Batch 375 processed. Sample translation:  ایک سرخ بالوں والی لڑکی اپنے پاؤں کے قریب سکیٹ بو
# Batch 376 processed. Sample translation:  ایک نوجوان لڑکا اور ایک نوجوان لڑکی فائر ٹرک پر ک
# Batch 377 processed. Sample translation:  ایک بیس بال کھلاڑی اپنے ونڈ اپ میں پچ پھینکنے کے
# Batch 378 processed. Sample translation:  ایک بلیزر اور پٹا پہنے نوجوان لڑکا پس منظر میں سر
# Batch 379 processed. Sample translation:  سرخ تہبند میں ایک آدمی گرل پر کھانا پکا رہا ہے، ج
# Batch 380 processed. Sample translation:  ایک خاندان ہری گھاس پر لیٹتے ہوئے دھوپ کے دن سے ل
# Batch 381 processed. Sample translation:  شارٹس اور ٹی شرٹ میں ایک چھوٹا لڑکا گھاس کے میدان
# Batch 382 processed. Sample translation:  نیلی یونیفارم پہنے بالغ، مرد فٹ بال کھلاڑیوں کا ا
# Batch 383 processed. Sample translation:  تین لیکروس کھلاڑی، دو ایک ہی ٹیم سے اور ایک مخالف
# Batch 384 processed. Sample translation:  دو تعمیراتی کارکن کام پر دن بھر سے بریک لگاتے ہوئ
# Batch 385 processed. Sample translation:  ایک رسی سے جڑی ایک خاتون کوہ پیما ڈرامائی پہاڑی پ
# Batch 386 processed. Sample translation:  دو واٹر پولو کھلاڑی گیند کے لیے کشتی لڑ رہے ہیں ج
# Batch 387 processed. Sample translation:  سفید ہیلمٹ، دھوپ، سیاہ لمبی بازو کی قمیض اور سیاہ
# Batch 388 processed. Sample translation:  ایک نوجوان ہیلمٹ اور حفاظتی لباس پہنے ہوئے ہے جب
# Batch 389 processed. Sample translation:  دو بچے، ایک بڑا لڑکا اور ایک چھوٹی لڑکی، اپنے موس
# Batch 390 processed. Sample translation:  پتھروں اور چٹانوں کے اوپر ایک ڈسپلے ٹیبل کے ساتھ
# Batch 391 processed. Sample translation:  ایک عورت قینچی سے کچھ کاٹ رہی ہے۔
# Batch 392 processed. Sample translation:  ایک پٹھے والا آدمی زمین پر بیٹھا ہوا پھل کاٹ رہا
# Batch 393 processed. Sample translation:  بہت سے لوگ کرسمس ٹری کے طور پر کھڑے ہیں یا سائیکل
# Batch 394 processed. Sample translation:  اسٹیج کے ساتھ عمارت کے اندر لوگوں کا ایک بڑا گروپ
# Batch 395 processed. Sample translation:  ایک چھوٹا لڑکا جس میں قمیض، شارٹس اور موزے ہیں، س
# Batch 396 processed. Sample translation:  یونیفارم میں لوگوں کا ایک گروپ ڈانس کی ریہرسل کر

# %% [markdown]
# # **Previous Code**

# %%
"""import os
from google.cloud import storage
from google.cloud import translate_v3 as translate

# Set up authentication
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/key.json'

# Initialize the Cloud Storage client
storage_client = storage.Client()

# Initialize the Translation API client
translate_client = translate.TranslationServiceClient()

# Set your project ID and bucket details
project_id = 'daring-diode-408818'
bucket_name = 'capurdusk'
source_file_name = '/content/eng_captions.xlsx'
destination_blob_name = 'captions.xlsx'  # The name of the file in the bucket

# Create a new bucket (unique across all Google Cloud)
# Note: Bucket names must be unique. If you get an error, try a different name.
bucket = storage_client.create_bucket(bucket_name)
print(f"Bucket {bucket.name} created.")

# Upload the file to Google Cloud Storage
blob = bucket.blob(destination_blob_name)
blob.upload_from_filename(source_file_name)
print(f"File {source_file_name} uploaded to {destination_blob_name}.")

"""
# Out:
# Bucket capurdusk created.
# File /content/eng_captions.xlsx uploaded to captions.xlsx.

# %%
"""# ... previous code ...
from google.protobuf.json_format import MessageToDict
import time

# Construct the resource name of the parent
location = 'us-central1'  # or other specific location
parent = f"projects/{project_id}/locations/{location}"

# Construct the request
gcs_source_uri = f"gs://{bucket_name}/{destination_blob_name}"
gcs_destination_prefix = f"translated_{destination_blob_name}"

# Specify the input configuration
input_configs_element = {
    "gcs_source": {"input_uri": gcs_source_uri}
}
input_configs = [input_configs_element]

# ... previous code ...

# Make sure the output_uri_prefix ends with a '/'
gcs_destination_prefix = f"gs://{bucket_name}/translated_{destination_blob_name}/"

# Specify the output configuration
gcs_destination = {"output_uri_prefix": gcs_destination_prefix}
output_config = {"gcs_destination": gcs_destination}

# Submit a batch translation request
operation = translate_client.batch_translate_document(
    parent=parent,
    source_language_code="en",
    target_language_codes=["ur"],  # Use Urdu as the target language
    input_configs=input_configs,
    output_config=output_config
)


response = operation.result()  # No need for timeout, as operation.done() is True
# Output the translated document location
print(f"Translated document written to {gcs_destination_prefix}")



# Output the translated document location
output_uri_prefix = response.output_config.gcs_destination.output_uri_prefix

# List objects with the given prefix.
bucket = storage_client.get_bucket(bucket_name)
blobs = list(bucket.list_blobs(prefix=gcs_destination_prefix))



# ... previous code ...

if blobs:
    # The folder where you want to save the translated file
    destination_folder = "/content/TranslatedCaptions"

    # Get the name of the first blob (file) in the list
    blob_name = blobs[0].name

    # The full path should include the filename, for example:
    destination_file_name = os.path.join(destination_folder, "translated_file.xlsx")

    # Download the translated file
    blob = bucket.blob(blob_name)
    blob.download_to_filename(destination_file_name)

    print(f"Translated file downloaded to {destination_file_name}")

else:
    print("No files found with the specified prefix.")
"""
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# <ipython-input-11-544b715e371b> in <cell line: 38>()
#      36
#      37
# ---> 38 response = operation.result()  # No need for timeout, as operation.done() is True
#      39 # Output the translated document location
#      40 print(f"Translated document written to {gcs_destination_prefix}")
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/future/polling.py in result(self, timeout, retry, polling)
#     259             # pylint: disable=raising-bad-type
#     260             # Pylint doesn't recognize that this is valid in this case.
# --> 261             raise self._exception
#     262
#     263         return self._result
#
# InternalServerError: 500 Error: INTERNAL. Job state: FAILED. 13: Error: INTERNAL. Job state: FAILED.
